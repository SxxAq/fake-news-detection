# %%
import pandas as pd

df_fake=pd.read_csv("data/Fake.csv")
df_true=pd.read_csv("data/True.csv")


# labeling fake/real news
df_fake["label"]=0
df_true["label"]=1

#combining the datasets, shuffling them randomly, and resetting the index
# to prepare a clean, randomized dataset for training a machine learning model.
df=pd.concat([df_fake,df_true]).sample(frac=1).reset_index(drop=True)


df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB
#                                                title  \
# 0  BLACK RADIO HOST: DEMOCRATS Have “Owned” Black...
# 1  Former Navy SEAL and Harvard Grad “Body-Slams”...
# 2  White House: Congress has more work to do on s...
# 3   Democrats SUE Republicans Over Plot To Rig El...
# 4  IT’S A WIN! Karen #Handel Beats Democrat…Crowd...
#
#                                                 text       subject  \
# 0  By Jesse Lee Peterson   President Donald Trump...      politics
# 1  Former Navy SEAL and GOP Rep. Scott Taylor, R-...     left-news
# 2  WASHINGTON (Reuters) - The White House on Frid...  politicsNews
# 3  Democrats appear to be completely fed up with ...          News
# 4  Karen Handel won a hard fought Congressional s...      politics
#
#                   date  label
# 0         Jan 30, 2017      0
# 1          Jul 4, 2017      0
# 2  September 23, 2016       1
# 3     October 26, 2016      0
# 4         Jun 21, 2017      0
